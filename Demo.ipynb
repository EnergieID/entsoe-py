# %%
from entsoe import EntsoeRawClient, EntsoePandasClient, Area
from settings import api_key
import pandas as pd

# %%
# Let's do all tests on data from yesterday

start = (pd.Timestamp.today(tz='Europe/Brussels') - pd.Timedelta(days=1)).normalize()
end = start + pd.Timedelta(days=1)
print(start, end)
# Out:
# 2020-10-17 00:00:00+02:00 2020-10-18 00:00:00+02:00

# %% [markdown]
# # Raw Client test

# %%
client = EntsoeRawClient(api_key=api_key)

# %%
response = client.query_day_ahead_prices(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <Publication_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-3:publicationdocument:7:0">
# 	<mRID>c41f7686f5bc4a63860aa7968b10a7e6</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A44</type>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:13:54Z</createdDateTime>
# 	<period.timeInterval>
# 		<start>2020-10-16T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A62</businessType>
# 		<in_Domain.mRID codingScheme="A01">10YBE----------2</in_Domain.mRID>
# ...

# %%
response = client.query_load(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <GL_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:generationloaddocument:3:0">
#     <mRID>9243bbd2bb2747e08ff78d5aafd06ac6</mRID>
#     <revisionNumber>1</revisionNumber>
#     <type>A65</type>
#     <process.processType>A16</process.processType>
#     <sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
#     <sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
#     <receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
#     <receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
#     <createdDateTime>2020-10-18T19:13:55Z</createdDateTime>
#     <time_Period.timeInterval>
#         <start>2020-10-16T22:00Z</start>
#         <end>2020-10-17T22:00Z</end>
#     </time_Period.timeInterval>
#     <TimeSeries>
#         <mRID>1</mRID>
# ...

# %%
response = client.query_load_forecast(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <GL_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:generationloaddocument:3:0">
#     <mRID>f35eaddc56e34085b7d16bcf5ee643f3</mRID>
#     <revisionNumber>1</revisionNumber>
#     <type>A65</type>
#     <process.processType>A01</process.processType>
#     <sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
#     <sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
#     <receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
#     <receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
#     <createdDateTime>2020-10-18T19:13:55Z</createdDateTime>
#     <time_Period.timeInterval>
#         <start>2020-10-16T22:00Z</start>
#         <end>2020-10-17T22:00Z</end>
#     </time_Period.timeInterval>
#     <TimeSeries>
#         <mRID>1</mRID>
# ...

# %%
response = client.query_generation_forecast(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <GL_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:generationloaddocument:3:0">
# 	<mRID>37c3528331b84d7fa87e1f7f7d724c2f</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A71</type>
# 	<process.processType>A01</process.processType>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:13:55Z</createdDateTime>
# 	<time_Period.timeInterval>
# 		<start>2020-10-16T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</time_Period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A01</businessType>
# 		<objectAggregation>A01</objectAggregation>
# ...

# %%
response = client.query_wind_and_solar_forecast(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <GL_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:generationloaddocument:3:0">
# 	<mRID>f005f317e2b44ec6bf2e0e679948d2e2</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A69</type>
# 	<process.processType>A01</process.processType>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:13:55Z</createdDateTime>
# 	<time_Period.timeInterval>
# 		<start>2020-10-16T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</time_Period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A94</businessType>
# 		<objectAggregation>A08</objectAggregation>
# ...

# %%
response = client.query_generation(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <GL_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:generationloaddocument:3:0">
# 	<mRID>eab08f313ca5414593787b3a473b7549</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A75</type>
# 	<process.processType>A16</process.processType>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:13:56Z</createdDateTime>
# 	<time_Period.timeInterval>
# 		<start>2020-10-16T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</time_Period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A01</businessType>
# 		<objectAggregation>A08</objectAggregation>
# ...

# %%
response = client.query_generation_per_plant(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <GL_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:generationloaddocument:3:0">
# 	<mRID>8f347d2c79a741cabac812787982a351</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A73</type>
# 	<process.processType>A16</process.processType>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:13:59Z</createdDateTime>
# 	<time_Period.timeInterval>
# 		<start>2020-10-16T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</time_Period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A01</businessType>
# 		<objectAggregation>A06</objectAggregation>
# ...

# %%
response = client.query_installed_generation_capacity(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <GL_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:generationloaddocument:3:0">
# 	<mRID>9bfd0e0cad064015975896b8e9fc6d42</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A68</type>
# 	<process.processType>A33</process.processType>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:13:59Z</createdDateTime>
# 	<time_Period.timeInterval>
# 		<start>2019-12-31T23:00Z</start>
# 		<end>2020-12-31T23:00Z</end>
# 	</time_Period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A37</businessType>
# 		<objectAggregation>A08</objectAggregation>
# ...

# %%
response = client.query_installed_generation_capacity_per_unit(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <GL_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:generationloaddocument:3:0">
# 	<mRID>d38065928b9d4ae3b8be6f63a77dd3b1</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A71</type>
# 	<process.processType>A33</process.processType>
# 	<sender_MarketParticipant.mRID codingScheme="A01" >10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:13:59Z</createdDateTime>
# 	<time_Period.timeInterval>
# 		<start>2020-10-16T00:00Z</start>
# 		<end>2020-10-17T00:00Z</end>
# 	</time_Period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A37</businessType>
# 		<objectAggregation>A06</objectAggregation>
# ...

# %%
response = client.query_crossborder_flows(country_code_from=Area.BE, country_code_to=Area.NL, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <Publication_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-3:publicationdocument:7:0">
# 	<mRID>edc1dd2e5adf4b6c82a786f07daaa3b5</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A11</type>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:14:00Z</createdDateTime>
# 	<period.timeInterval>
# 		<start>2020-10-16T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A66</businessType>
# 		<in_Domain.mRID codingScheme="A01">10YNL----------L</in_Domain.mRID>
# ...

# %%
response = client.query_scheduled_exchanges(country_code_from=Area.BE, country_code_to=Area.NL, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <Publication_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-3:publicationdocument:7:0">
# 	<mRID>59c87d4e97424570938a99c124610fb4</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A09</type>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:14:00Z</createdDateTime>
# 	<period.timeInterval>
# 		<start>2020-10-16T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A06</businessType>
# 		<in_Domain.mRID codingScheme="A01">10YNL----------L</in_Domain.mRID>
# ...

# %%
response = client.query_net_transfer_capacity_dayahead(country_code_from=Area.BE, country_code_to=Area.NL, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <Publication_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-3:publicationdocument:7:0">
# 	<mRID>6bc2b41cf9454a559aa8dd3ce01d428b</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A61</type>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:14:00Z</createdDateTime>
# 	<period.timeInterval>
# 		<start>2020-10-16T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A27</businessType>
# 		<in_Domain.mRID codingScheme="A01">10YNL----------L</in_Domain.mRID>
# ...

# %%
response = client.query_net_transfer_capacity_weekahead(country_code_from=Area.BE, country_code_to=Area.NL, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <Publication_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-3:publicationdocument:7:0">
# 	<mRID>627156b6ff324f1f960439c32beb5df2</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A61</type>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:14:00Z</createdDateTime>
# 	<period.timeInterval>
# 		<start>2020-10-11T22:00Z</start>
# 		<end>2020-10-18T22:00Z</end>
# 	</period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A27</businessType>
# 		<in_Domain.mRID codingScheme="A01">10YNL----------L</in_Domain.mRID>
# ...

# %%
response = client.query_net_transfer_capacity_monthahead(country_code_from=Area.BE, country_code_to=Area.NL, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <Publication_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-3:publicationdocument:7:0">
# 	<mRID>32cc9bb06d3d46da8a80c4cdc50812bb</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A61</type>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:14:01Z</createdDateTime>
# 	<period.timeInterval>
# 		<start>2020-09-30T22:00Z</start>
# 		<end>2020-10-31T23:00Z</end>
# 	</period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A27</businessType>
# 		<in_Domain.mRID codingScheme="A01">10YNL----------L</in_Domain.mRID>
# ...

# %%
response = client.query_net_transfer_capacity_yearahead(country_code_from=Area.BE, country_code_to=Area.NL, start=start, end=end)
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <Publication_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-3:publicationdocument:7:0">
# 	<mRID>28a42967b88d457fa1a14782522dc29c</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A61</type>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:14:01Z</createdDateTime>
# 	<period.timeInterval>
# 		<start>2019-12-31T23:00Z</start>
# 		<end>2020-12-31T23:00Z</end>
# 	</period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# 		<businessType>A27</businessType>
# 		<in_Domain.mRID codingScheme="A01">10YNL----------L</in_Domain.mRID>
# ...

# %%
response = client.query_imbalance_prices(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# b'PK\x03\x04\x14\x00\x08\x08\x08\x00\xc0\x99RQ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x002\x00\x00\x00001-IMBALANCE_PRICES_202010162200-202010172200.xml\xed\x9c]O\xe38\x14\x86\xafg~\x05\xea=\xae\xed$NR\x85\x8e@\xccj\xe7\x82\x15\x82\xa2\xfd\xb8\xa9B\xb0\xd8hh\x82\xd2\x94]\xfe\xfd:)\xb4;P\xe0D=:G^-\x1a1!v\x92\xc7\x8e\x93\xd7\xc7v\xde\xec\xcb\xdf\x8b\xbb\x83\x07\xdb,\xcb\xba:\x1a)!G\x07\xb6*\xea\x9b\xb2\xba=\x1a]\xcd~:LF_\xa6\x9f\xb3\x93\xfc.\xaf\n\xb7s~\x967\xdfm{Z\x17\xab\x85\xad\xda\x03wx\xb5<\x1a\xad\x9ajR\xda\xc2\xe8@G"\x88\xd4\xa4-\xa2\xf8\xaf[e&a\xa4\x0e\xcd\xe4\xfa\xf9\xf8\x9b\xa7\x03\'\xc1D\x8e\xa6\x9f?e\x8b\x8bo\xa7\xd3 N\x8d4\xd76\x96A\x11\xc6R\xa7i\x1c\x166\xd1*\xbfNT\x91\x87\xd9\xb8\xcf\xe6\xb27\xf6\xa1\xecX\x7fY-\xaem3U\xd9\xf8\xc5\x1e\x97\xa7}\xbc\xb7\xd3\xe3$\xca\xc6\xfd\x96\xdbs\xdf\xd4\x85].\xc5\xd3\xff\xb3>\x832\xd9xW\x82\xcb\xbf\xb4\xd5\x8dm\x9e\xcaz\x9e7mY\x94\xf7y\xd5\x8a\x0e\xe3`]=\x97\xc5\x9fva\x8fF\xc7R\x8d\xa6J\xfe\xa6\xa4T\xc7\xfd\xaf0\x92\xd9\xf8\xddS\xb
# ...

# %%
response = client.query_contracted_reserve_prices(country_code=Area.BE, start=start, end=end, type_marketagreement_type='A01')
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <Balancing_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:balancingdocument:3:0">
# 	<mRID>8e8f590aa44143249c1606e466524330</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A89</type>
# 	<process.processType>A34</process.processType>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:14:02Z</createdDateTime>
# 	<controlArea_Domain.mRID codingScheme="A01">10YBE----------2</controlArea_Domain.mRID>
# 	<period.timeInterval>
# 		<start>2020-10-15T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# ...

# %%
response = client.query_contracted_reserve_amount(country_code=Area.BE, start=start, end=end, type_marketagreement_type='A01')
print(response)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <Balancing_MarketDocument xmlns="urn:iec62325.351:tc57wg16:451-6:balancingdocument:3:0">
# 	<mRID>777b71c6fcb948acb1ed22865a5e30fa</mRID>
# 	<revisionNumber>1</revisionNumber>
# 	<type>A81</type>
# 	<process.processType>A34</process.processType>
# 	<sender_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</sender_MarketParticipant.mRID>
# 	<sender_MarketParticipant.marketRole.type>A32</sender_MarketParticipant.marketRole.type>
# 	<receiver_MarketParticipant.mRID codingScheme="A01">10X1001A1001A450</receiver_MarketParticipant.mRID>
# 	<receiver_MarketParticipant.marketRole.type>A33</receiver_MarketParticipant.marketRole.type>
# 	<createdDateTime>2020-10-18T19:14:03Z</createdDateTime>
# 	<controlArea_Domain.mRID codingScheme="A01">10YBE----------2</controlArea_Domain.mRID>
# 	<period.timeInterval>
# 		<start>2020-10-15T22:00Z</start>
# 		<end>2020-10-17T22:00Z</end>
# 	</period.timeInterval>
# 	<TimeSeries>
# 		<mRID>1</mRID>
# ...

# %%
response = client.query_unavailability_of_generation_units(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# b'PK\x03\x04\x14\x00\x08\x08\x08\x00\xc1\x99RQ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00I\x00\x00\x00001-001-PLANNED_UNAVAIL_OF_GENERATION_UNITS_202009280800-202010211700.xml\xadVmo\xa2@\x10\xfe\xdc\xfe\n\xe3wa\xc1b-A\x1a[\xcf\xc4\xe4<\x8d\xd2k\xaf_\x0c\x85\x89\xdd\x1e,v\x01\xdb\xde\xaf\xbfaWQ)\x82\xf7B\x0c\xc2\xce\xcc3\xb3\xcf\xb3;\x8bu\xfd\x1e\x06\x8d5\xf0\x98F\xac\xd7\xd4\x14\xd2l\x00\xf3"\x9f\xb2e\xafy\xe7\x0c[\xdd\xe6\xb5}n\xdd1w\xed\xd2\xc0}\xa2\x01M>\x16c\x97\xff\x84d\x10yi\x08,i \x06\x8b{\xcd\x943\x93\x82\xd7\xd1\xdb\xba\xa1\xb4\r\xcdL<\xe3\xf2m\xa9u\xcc\x0bCku\xcc(M\xdc%\xf8\x9b(\xb3mb2\xfb\xbc\x81\x97\x15\xceF\x03\x9b|\x1f\xdfvI\xfc\xfe\xebe\x18\xbf~\xbdzY\x0c\xbb\xc3\xe9\xd2R\x85Q\xfaqX\xd3\xac\xd4oi\xf8\x04\xdc\xeeXjaD\xba%\x1f+\xb0\xfb]b\xa9\xe2I\x0e\xaex\xe4A\x1c+\x9b\x7fG\xf8\xe8\x08Qf\x90!\x1e\x077\x01\x7f\x807\x87\x86`\xebD\'-\r\x7fm\x87\\\x9a\xa4k^t\x1f-\xb5\xe8%cc`>\xf0\rUS\x97\'\xd4\xa3+\x97%J6\x9d\x86\xa4x\xee=C\x08\xbdf\x9fhM[#\x0f\x1a!Z_\xdc.\x0c,\xbe\x12
01\x07\x97\xd7\xfdR\xf0\x80\xd1\xd4w=wh{C\x1c\xa8tx\xf1\xf3\t\xfb\xc1`\x88-?(J\x95<\xd1\xac^\x15x\x018\x0b_\xf7\xe0!\xcb\xd9\xedM8V\xf7\x0f\xe9\'o\xf4e~g\xf9\x03\xeb\x1b\x9e\x8d\xae\x9e\x7f\x12GO\x1a\x9c\xa0kV\x85zW.\x1f\xa9\x08/\x89\xb3g10\xf5\xbc\xa2at\x01\xd3zd\x8c+Q\xa4TJ\xbb\xfe\x8e5\xc6\xf5\x89\xd35a\x96\xa4\x82&\x8af7\xf0\x11\xb3%\r]\xe4"\x0b\xf9\x16rct\x11`\xf8\x1b\xfcC\x9c}\x94Y+)\xcf\xa8\xa8S5M\x84b)[%\\\xd9\xd5vz&\xc5\xf3\xf4+]\xd2\xeb~\x84p?\xc4\xe83F\x08G\xfac0D\
# ...

# %%
response = client.query_withdrawn_unavailability_of_generation_units(country_code=Area.BE, start=start, end=end)
print(response)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/EnergieID/entsoe-py/entsoe/entsoe.py in _base_request(self, params, start, end)
#     117         try:
# --> 118             response.raise_for_status()
#     119         except requests.HTTPError as e:
#
# /usr/local/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 400 Client Error: Bad Request for url: https://transparency.entsoe.eu/api?documentType=A80&biddingZone_domain=10YBE----------2&docStatus=A13&securityToken=c0f5325c-862a-4fd8-8797-bff66577cb07&periodStart=202010162200&periodEnd=202010172200
#
# During handling of the above exception, another exception occurred:
#
# NoMatchingDataError                       Traceback (most recent call last)
# ...

# %% [markdown]
# # Pandas Client Test

# %%
client = EntsoePandasClient(api_key=api_key)

# %%
client.query_day_ahead_prices(country_code=Area.BE, start=start, end=end)
# Out:
# 2020-10-17 00:00:00+02:00    49.03
# 2020-10-17 01:00:00+02:00    44.37
# 2020-10-17 02:00:00+02:00    40.00
# 2020-10-17 03:00:00+02:00    36.26
# 2020-10-17 04:00:00+02:00    35.59
# 2020-10-17 05:00:00+02:00    36.91
# 2020-10-17 06:00:00+02:00    37.35
# 2020-10-17 07:00:00+02:00    44.33
# 2020-10-17 08:00:00+02:00    46.22
# 2020-10-17 09:00:00+02:00    48.08
# 2020-10-17 10:00:00+02:00    45.92
# 2020-10-17 11:00:00+02:00    43.53
# 2020-10-17 12:00:00+02:00    42.04
# 2020-10-17 13:00:00+02:00    38.94
# 2020-10-17 14:00:00+02:00    36.18
# 2020-10-17 15:00:00+02:00    36.10
# 2020-10-17 16:00:00+02:00    37.68
# 2020-10-17 17:00:00+02:00    43.50
# 2020-10-17 18:00:00+02:00    48.25
# 2020-10-17 19:00:00+02:00    50.46
# 2020-10-17 20:00:00+02:00    48.81
# 2020-10-17 21:00:00+02:00    43.00
# 2020-10-17 22:00:00+02:00    43.92
# 2020-10-17 23:00:00+02:00    47.98
# dtype: float64

# %%
client.query_load(country_code=Area.BE, start=start, end=end)
# Out:
# 2020-10-17 00:00:00+02:00    8620.0
# 2020-10-17 10:00:00+02:00  1030.0            0.0           4.0
# 2020-10-17 11:00:00+02:00  1388.0            0.0           4.0
# 2020-10-17 12:00:00+02:00  1479.0           24.0           5.0
# 2020-10-17 13:00:00+02:00  1410.0           18.0          10.0
# ...

# %%
client.query_generation(country_code=Area.BE, start=start, end=end)
# Out:
#                            Biomass  Fossil Gas  Fossil Oil  \
# 2020-10-17 00:00:00+02:00     60.0      3505.0         0.0
# 2020-10-17 01:00:00+02:00     47.0      3309.0         0.0
# 2020-10-17 02:00:00+02:00     47.0      3340.0         0.0
# 2020-10-17 03:00:00+02:00     47.0      2961.0         0.0
# 2020-10-17 04:00:00+02:00     47.0      2910.0         0.0
# 2020-10-17 05:00:00+02:00     48.0      3094.0         0.0
# 2020-10-17 06:00:00+02:00     47.0      3093.0         0.0
# 2020-10-17 07:00:00+02:00     48.0      3089.0         0.0
# 2020-10-17 08:00:00+02:00     48.0      3111.0         0.0
# 2020-10-17 09:00:00+02:00     47.0      3116.0         0.0
# 2020-10-17 10:00:00+02:00     48.0      2961.0         0.0
# 2020-10-17 11:00:00+02:00     48.0      3132.0         0.0
# 2020-10-17 12:00:00+02:00     47.0      3188.0         0.0
# 2020-10-17 13:00:00+02:00     47.0      3084.0         0.0
# 2020-10-17 14:00:00+02:00     47.0      3044.0         0.0
# ...

# %%
client.query_installed_generation_capacity(country_code=Area.BE, start=start, end=end)
# Out:
#                            Biomass  Fossil Gas  Fossil Hard coal  Fossil Oil  \
# 2020-01-01 00:00:00+01:00    634.0      6762.0             470.0       321.0
#
#                            Hydro Pumped Storage  \
# 2020-01-01 00:00:00+01:00                1308.0
#
#                            Hydro Run-of-river and poundage  Nuclear  Other  \
# 2020-01-01 00:00:00+01:00                            181.0   5943.0   19.0
#
#                             Solar  Waste  Wind Offshore  Wind Onshore
# 2020-01-01 00:00:00+01:00  3887.0  362.0         2044.0        2416.0

# %%
client.query_installed_generation_capacity_per_unit(country_code=Area.BE, start=start, end=end)
# Out:
#                       Bidding Zone Installed Capacity [MW]  \
# 22WSAINT-000221B  10YBE----------2                     350
# 22WDOELX40000793  10YBE----------2                    1039
# 22WCOOXII000070C  10YBE----------2                     690
# 22WDROGEN0000863  10YBE----------2                     465
# 22WINESCO000149P  10YBE----------2                     138
# 22W201902131---T  10YBE----------2                   369.6
# 22WMARCIN000179H  10YBE----------2                     413
# 22W20200608A---8  10YBE----------2                     237
# 22WSCHELD0002261  10YBE----------2                     140
# 22W201909111---M  10YBE----------2                   219.1
# 22WTHORNT000237E  10YBE----------2                   147.6
# 22WDOELX3000078D  10YBE----------2                    1006
# 22WTHORNT000238C  10YBE----------2                   177.6
# 22WT-POWE000244W  10YBE----------2                     422
# 22WCOOXIX000067T  10YBE----------2                     474
# ...

# %%
client.query_crossborder_flows(country_code_from=Area.BE, country_code_to=Area.NL, start=start, end=end)
# Out:
# 2020-10-17 00:00:00+02:00    0.0
# 2020-10-17 01:00:00+02:00    0.0
# 2020-10-17 02:00:00+02:00    0.0
# 2020-10-17 03:00:00+02:00    0.0
# 2020-10-17 04:00:00+02:00    0.0
# 2020-10-17 05:00:00+02:00    0.0
# 2020-10-17 06:00:00+02:00    0.0
# 2020-10-17 07:00:00+02:00    0.0
# 2020-10-17 08:00:00+02:00    0.0
# 2020-10-17 09:00:00+02:00    0.0
# 2020-10-17 10:00:00+02:00    0.0
# 2020-10-17 11:00:00+02:00    0.0
# 2020-10-17 12:00:00+02:00    0.0
# 2020-10-17 13:00:00+02:00    0.0
# 2020-10-17 14:00:00+02:00    0.0
# 2020-10-17 15:00:00+02:00    0.0
# 2020-10-17 16:00:00+02:00    0.0
# 2020-10-17 17:00:00+02:00    0.0
# 2020-10-17 18:00:00+02:00    0.0
# 2020-10-17 19:00:00+02:00    0.0
# 2020-10-17 20:00:00+02:00    0.0
# 2020-10-17 21:00:00+02:00    0.0
# 2020-10-17 22:00:00+02:00    0.0
# 2020-10-17 23:00:00+02:00    0.0
# dtype: float64

# %%
client.query_scheduled_exchanges(country_code_from=Area.BE, country_code_to=Area.NL, start=start, end=end)
# Out:
# 2020-10-17 00:00:00+02:00      0.0
# 2020-10-17 01:00:00+02:00      0.0
# 2020-10-17 02:00:00+02:00      0.0
# 2020-10-17 03:00:00+02:00      0.0
# 2020-10-17 04:00:00+02:00      6.0
# 2020-10-17 05:00:00+02:00      0.0
# 2020-10-17 06:00:00+02:00      0.0
# 2020-10-17 07:00:00+02:00      0.0
# 2020-10-17 08:00:00+02:00      0.0
# 2020-10-17 09:00:00+02:00    105.0
# 2020-10-17 10:00:00+02:00     85.0
# 2020-10-17 11:00:00+02:00    237.0
# 2020-10-17 12:00:00+02:00      3.0
# 2020-10-17 13:00:00+02:00      0.0
# 2020-10-17 14:00:00+02:00      4.0
# 2020-10-17 15:00:00+02:00     21.0
# 2020-10-17 16:00:00+02:00     77.0
# 2020-10-17 17:00:00+02:00    606.0
# 2020-10-17 18:00:00+02:00     98.0
# 2020-10-17 19:00:00+02:00     45.0
# 2020-10-17 20:00:00+02:00      9.0
# 2020-10-17 21:00:00+02:00      0.0
# 2020-10-17 22:00:00+02:00      0.0
# 2020-10-17 23:00:00+02:00     12.0
# dtype: float64

# %%
client.query_imbalance_prices(country_code=Area.BE, start=start, end=end)
# Out:
#                              Long   Short
# 2020-10-17 00:00:00+02:00   67.94   67.94
# 2020-10-17 00:15:00+02:00  106.12  106.12
# 2020-10-17 00:30:00+02:00   12.00   12.00
# 2020-10-17 00:45:00+02:00   12.00   12.00
# 2020-10-17 01:00:00+02:00   62.64   62.64
# ...                           ...     ...
# 2020-10-17 22:45:00+02:00   64.19   64.19
# 2020-10-17 23:00:00+02:00   75.00   75.00
# 2020-10-17 23:15:00+02:00   11.59   11.59
# 2020-10-17 23:30:00+02:00   12.00   12.00
# 2020-10-17 23:45:00+02:00   11.32   11.32
#
# [96 rows x 2 columns]

# %%
client.query_contracted_reserve_prices(country_code=Area.BE, start=start, end=end, type_marketagreement_type='A01')
# Out:
#                            Automatic frequency restoration reserve - Down  \
# 2020-10-17 00:00:00+02:00                                            1.41
# 2020-10-17 01:00:00+02:00                                            1.41
# 2020-10-17 02:00:00+02:00                                            1.41
# 2020-10-17 03:00:00+02:00                                            1.41
# 2020-10-17 04:00:00+02:00                                            1.17
# 2020-10-17 05:00:00+02:00                                            1.17
# 2020-10-17 06:00:00+02:00                                            1.17
# 2020-10-17 07:00:00+02:00                                            1.17
# 2020-10-17 08:00:00+02:00                                            1.00
# 2020-10-17 09:00:00+02:00                                            1.00
# 2020-10-17 10:00:00+02:00                                            1.00
# 2020-10-17 11:00:00+02:00                                            1.00
# ...

# %%
client.query_contracted_reserve_amount(country_code=Area.BE, start=start, end=end, type_marketagreement_type='A01')
# Out:
#                            Automatic frequency restoration reserve - Down  \
# 2020-10-17 00:00:00+02:00                                           145.0
# 2020-10-17 01:00:00+02:00                                           145.0
# 2020-10-17 02:00:00+02:00                                           145.0
# 2020-10-17 03:00:00+02:00                                           145.0
# 2020-10-17 04:00:00+02:00                                           145.0
# 2020-10-17 05:00:00+02:00                                           145.0
# 2020-10-17 06:00:00+02:00                                           145.0
# 2020-10-17 07:00:00+02:00                                           145.0
# 2020-10-17 08:00:00+02:00                                           145.0
# 2020-10-17 09:00:00+02:00                                           145.0
# 2020-10-17 10:00:00+02:00                                           145.0
# 2020-10-17 11:00:00+02:00                                           145.0
# ...

# %%
client.query_unavailability_of_generation_units(country_code=Area.BE, start=start, end=end)
# Out:
# Empty DataFrame
# Columns: [avail_qty, biddingzone_domain, businesstype, curvetype, docstatus, end, nominal_power, plant_type, production_resource_id, production_resource_location, production_resource_name, pstn, qty_uom, resolution, start]
# Index: []

# %%
client.query_unavailability_of_production_units(country_code=Area.BE, start=start, end=end)
# Out:
# Empty DataFrame
# Columns: [avail_qty, biddingzone_domain, businesstype, curvetype, docstatus, end, nominal_power, plant_type, production_resource_id, production_resource_location, production_resource_name, pstn, qty_uom, resolution, start]
# Index: []

# %%
client.query_unavailability_transmission(country_code_from=Area.BE, country_code_to=Area.NL, start=start, end=end)
# Out:
# Empty DataFrame
# Columns: [docstatus, businesstype, in_domain, out_domain, qty_uom, curvetype, start, end, resolution, pstn, avail_qty]
# Index: []

# %%
client.query_withdrawn_unavailability_of_generation_units(country_code=Area.BE, start=start, end=end)
# Out:
# ---------------------------------------------------------------------------
# NoMatchingDataError                       Traceback (most recent call last)
# <ipython-input-43-12c596cb9159> in <module>()
# ----> 1 client.query_withdrawn_unavailability_of_generation_units(country_code=Area.BE, start=start, end=end)
#
# ~/EnergieID/entsoe-py/entsoe/entsoe.py in query_withdrawn_unavailability_of_generation_units(self, country_code, start, end)
#    1352         """
#    1353         df = self.query_unavailability_of_generation_units(
# -> 1354             country_code=country_code, start=start, end=end, docstatus='A13')
#    1355         df = df.truncate(before=start, after=end)
#    1356         return df
#
# ~/EnergieID/entsoe-py/entsoe/entsoe.py in query_unavailability_of_generation_units(self, country_code, start, end, docstatus, periodstartupdate, periodendupdate)
#    1273             country_code=country_code, start=start, end=end, doctype="A80",
# ...

# %%
